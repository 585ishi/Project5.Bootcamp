# %%
import pandas as pd

# %% [markdown]
# # INFLATION DATASET

# %%
inflation_file = "Data/inflation_1810025601-noSymbol.csv"
inflation_df = pd.read_csv(inflation_file, encoding="utf-8")
inflation_df.head(15)
# Out:
#    Reference period  Percent  2002=100
# 0      January 2003      2.5     101.7
# 1     February 2003      2.5     101.9
# 2        March 2003      2.4     101.9
# 3        April 2003      2.0     101.6
# 4          May 2003      2.0     102.0
# 5         June 2003      1.9     102.0
# 6         July 2003      1.8     102.1
# 7       August 2003      1.8     102.2
# 8    September 2003      1.9     102.4
# 9      October 2003      1.9     102.7
# 10    November 2003      1.7     102.9
# 11    December 2003      1.9     103.0
# 12     January 2004      1.6     103.1
# 13    February 2004      1.5     103.1
# 14       March 2004      1.6     103.2

# %% [markdown]
# # LIABILITES DATASET

# %%
liabilities_file = "Data/liabilities_3610063901-noSymbol.csv"
liabilities_df = pd.read_csv(liabilities_file, encoding="utf-8")
liabilities_df.head(20)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/sz/rr0n97ys1lggyvv12rb50jqm0000gn/T/ipykernel_813/2651680890.py in <module>
#       1 liabilities_file = "Data/liabilities_3610063901-noSymbol.csv"
# ----> 2 liabilities_df = pd.read_csv(liabilities_file, encoding="utf-8")
#       3 liabilities_df.head(20)
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
clean_liabilites_df = liabilities_df.dropna(how = "any")
clean_liabilities_df.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/sz/rr0n97ys1lggyvv12rb50jqm0000gn/T/ipykernel_813/1627214747.py in <module>
# ----> 1 clean_liabilites_df = liabilities_df.dropna(how = "any")
#       2 clean_liabilities_df.count()
#
# NameError: name 'liabilities_df' is not defined

# %% [markdown]
# # SALES DATASET

# %%
sales_file = "Data/SalesForCourse_table.csv"
sales_df = pd.read_csv(sales_file, encoding="utf-8")
sales_df.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/sz/rr0n97ys1lggyvv12rb50jqm0000gn/T/ipykernel_813/2240988041.py in <module>
#       1 sales_file = "Data/SalesForCourse_table.csv"
# ----> 2 sales_df = pd.read_csv(sales_file, encoding="utf-8")
#       3 sales_df.head(5)
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
sales_df.count()
# Out:
# index               34867
# Date                34866
# Year                34866
# Month               34866
# Customer Age        34866
# Customer Gender     34866
# Country             34866
# State               34866
# Product Category    34866
# Sub Category        34866
# Quantity            34866
# Unit Cost           34866
# Unit Price          34866
# Cost                34866
# Revenue             34867
# Column1              2574
# dtype: int64

# %% [markdown]
# # CONSUMER SPENDING

# %%
spending_file = "Data/spending_3610012401-noSymbol.csv"
spending_df = pd.read_csv(spending_file, encoding="utf-8", on_bad_lines='skip')
spending_df.head(15)
# Out:
#    Estimates Household final consumption expenditure  \
# 0    Q1 2003                                 168,235
# 1    Q2 2003                                 169,357
# 2    Q3 2003                                 171,775
# 3    Q4 2003                                 171,840
# 4    Q1 2004                                 175,190
# 5    Q2 2004                                 177,340
# 6    Q3 2004                                 179,268
# 7    Q4 2004                                 181,142
# 8    Q1 2005                                 184,591
# 9    Q2 2005                                 187,126
# 10   Q3 2005                                 189,385
# 11   Q4 2005                                 191,311
# 12   Q1 2006                                 194,786
# 13   Q2 2006                                 197,264
# 14   Q3 2006                                 199,875
#
#    Food and non-alcoholic beverages    Food Non-alcoholic beverages  \
# ...

# %%
spending_df.count()
# Out:
# Estimates                                  84
# Household final consumption expenditure    81
# Food and non-alcoholic beverages           80
# Food                                       80
# Non-alcoholic beverages                    80
#                                            ..
# Undertaking and other funeral services     80
# Legal and other services                   80
# Net expenditure abroad                     80
# Expenditure by Canadians abroad            80
# Expenditure by non-residents in Canada     80
# Length: 117, dtype: int64

# %%
clean_spending_df = spending_df.dropna(how = "any")
clean_spending_df.count()
# Out:
# Estimates                                  80
# Household final consumption expenditure    80
# Food and non-alcoholic beverages           80
# Food                                       80
# Non-alcoholic beverages                    80
#                                            ..
# Undertaking and other funeral services     80
# Legal and other services                   80
# Net expenditure abroad                     80
# Expenditure by Canadians abroad            80
# Expenditure by non-residents in Canada     80
# Length: 117, dtype: int64
